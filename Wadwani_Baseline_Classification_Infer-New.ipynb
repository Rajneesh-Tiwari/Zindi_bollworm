# %% [markdown]
# ### Regression notebook for Wadhwani AI competition

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import os
import gc
import random
from glob import glob
from sklearn.model_selection import GroupKFold, KFold, StratifiedKFold
import warnings
import pickle
import json
import re
import time
import sys
from requests import get
import multiprocessing
import joblib
import torch
from torch.utils.data import Dataset, DataLoader
import transformers
import torch.nn as nn
import torch.nn.functional as F
from torch.cuda.amp import GradScaler, autocast
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
import timm
from sklearn.preprocessing import minmax_scale
import matplotlib.pyplot as plt
import albumentations as A
from albumentations.pytorch import ToTensorV2
import cv2,torchvision
from ipyexperiments.ipyexperiments import IPyExperimentsPytorch
from timm.optim.optim_factory import create_optimizer_v2
from timm import utils
from fastprogress.fastprogress import format_time
from fastai.vision.all import *


class CFG:
    seed = 46
    n_splits = 5
    SZ = 1024
    debug = False
    BS = 16
    EP = 10
    MODEL = 'tf_efficientnet_b2_ns'
    LR = 5e-03
    WD = 1e-08
    debug = False

random.seed(CFG.seed)
os.environ["PYTHONHASHSEED"] = str(CFG.seed)
np.random.seed(CFG.seed)
plt.rcParams["font.size"] = 13
warnings.filterwarnings('ignore')

# %%
set_seed(CFG.seed)

# %%
DIR = '///mnt/c/Personal/Competitions/Zindi/Wadhwani AI/data/'
IMG_PATH = '///mnt/c/Personal/Competitions/Zindi/Wadhwani AI/data/images'
submit = pd.read_csv(os.path.join(DIR,'SampleSubmission.csv'))
train = pd.read_csv(os.path.join(DIR,'Train.csv'))
test_df = pd.read_csv(os.path.join(DIR,'Test.csv'))

if CFG.debug:
    train = train.sample(frac=0.1).reset_index(drop=True)
    
VERSION = "NB_EXP_V0_001_Classification"
MODEL_FOLDER = Path(f"///mnt/c/Personal/Competitions/Zindi/Wadhwani AI/runs/Classification/{VERSION}/")
os.makedirs(MODEL_FOLDER,exist_ok=True)
KERNEL_TYPE = f"{CFG.MODEL}_{CFG.SZ}_bs{CFG.BS}_ep{CFG.EP}_lr{str(CFG.LR).replace('-','')}_wd{str(CFG.WD).replace('-','')}"

print(MODEL_FOLDER)
print(KERNEL_TYPE)
# Out:
# /mnt/c/Personal/Competitions/Zindi/Wadhwani AI/runs/Classification/NB_EXP_V0_001_Classification
# tf_efficientnet_b2_ns_1024_bs16_ep10_lr0.005_wd1e08

# %%
def make_train_dataset():
    train_new_pbw = pd.DataFrame()
    train_new_pbw['image_id_worm']= train['image_id_worm'].unique()
    train_new_pbw = pd.merge(train_new_pbw,train[train['worm_type']=='pbw'].reset_index(drop=True),on='image_id_worm',how='left')
    train_new_pbw['worm_type'] = 'pbw'
    train_new_pbw.fillna(0,inplace=True)
    
    train_new_abw = pd.DataFrame()
    train_new_abw['image_id_worm']= train['image_id_worm'].unique()
    train_new_abw = pd.merge(train_new_abw,train[train['worm_type']=='abw'].reset_index(drop=True),on='image_id_worm',how='left')
    train_new_abw['worm_type'] = 'abw'
    train_new_abw.fillna(0,inplace=True)
    
    train_out = pd.concat([train_new_pbw,train_new_abw],0).reset_index(drop=True)
    
    assert len(train_out) == train['image_id_worm'].nunique()*2
    train_out = pd.pivot(train_out,'image_id_worm','worm_type','number_of_worms').reset_index()
    train_out[['abw','pbw']] = train_out[['abw','pbw']].astype(int)
    
    train_out['abw_cls'] = (train_out['abw']>0).astype(int)
    train_out['pbw_cls'] = (train_out['pbw']>0).astype(int)
    
    return train_out

train_new = make_train_dataset()

# %%
train_new.head(1)
# Out:
# worm_type                    image_id_worm  abw  pbw  abw_cls  pbw_cls
# 0          id_0002ea6f15c7fa6f4c221783.jpg    0   51        0        1

# %% [markdown]
# ### Get kfolds

# %%
train_files = []
val_files = []
fold = []

for folds in [0,1,2,3,4]:
    files = list(pd.read_csv(f'///mnt/c/Personal/Competitions/Zindi/Wadhwani AI/data/splits/fold{folds}.txt',header=None)[0].apply(lambda x:x.split("/")[-1]))
    fold.append([folds]*len(files))
    train_files.append(files)

train_files= ([item for sublist in train_files for item in sublist])
fold= ([item for sublist in fold for item in sublist])
fold_dict = dict(zip(train_files,fold))
train_new['fold'] = train_new['image_id_worm'].map(fold_dict)

# %%
train_new.head()
# Out:
# worm_type                    image_id_worm  abw  pbw  abw_cls  pbw_cls  fold
# 0          id_0002ea6f15c7fa6f4c221783.jpg    0   51        0        1   1.0
# 1          id_0005ef295aafe6acc63587db.jpg    0    8        0        1   0.0
# 2          id_00084298dd030a500033ff78.jpg    0    0        0        0   NaN
# 3          id_00093f2c76f6488737325859.jpg    0   12        0        1   2.0
# 4          id_000b2e6c437c643f25d4a6c3.jpg    0   87        0        1   0.0

# %%
train_new = train_new[~train_new['fold'].isna()].reset_index(drop=True)
train_new['fold'] = train_new['fold'].astype(int)
print(train_new['fold'].unique())
# Out:
# [1 0 2 4 3]

# %%
test_df.head(1)
# Out:
#                      image_id_worm
# 0  id_00332970f80fa9a47a39516d.jpg

# %% [markdown]
# #### Data loader

# %%
class WadhwaniDataset(Dataset):
    def __init__(self,
                 df=train_new,
                 mode='train',
                augs = None):
        
        self.augs = augs
        self.df = df
        self.mode  = mode
        
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, ix):
        image_id = self.df.loc[ix,'image_id_worm']
        img_path = f'{IMG_PATH}/{image_id}'
        
        img = Image.open(img_path).convert("RGB")
        img = np.array(img)
        
        if self.augs is not None:
            img = self.augs(image=img)['image']
    
        if self.mode == 'test':
            return img
        
        label = torch.tensor(self.df[['abw_cls','pbw_cls']].loc[ix]).float()
        return img, label, image_id

# %%
def worker_init_fn(worker_id):
    """
    Handles PyTorch x Numpy seeding issues.
    Args:
        worker_id (int): Id of the worker.
    """
    np.random.seed(np.random.get_state()[1][0] + worker_id)

# %% [markdown]
# ### Augmentations

# %%
TRAIN_AUG = A.Compose([
#     A.RandomResizedCrop(height=SZ, width=SZ, p=1.0, scale=(0.72, 1.0)),
#     A.Transpose(p=0.5),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.ShiftScaleRotate(rotate_limit=45, border_mode=0, p=0.75),
    A.RandomBrightnessContrast(brightness_limit=0.1, contrast_limit=0.1),
    A.Blur(p=0.5),
#     A.CoarseDropout(max_height=int(32*(CFG.SZ/512)), max_width=int(32*(CFG.SZ/512)), p=0.75),
    A.Resize(CFG.SZ,CFG.SZ,p=1),
    A.Normalize(),
    ToTensorV2(),
])

VALID_AUG = A.Compose([
#     A.SmallestMaxSize(max_size=CFG.SZ + 16, p=1.0),
#     A.CenterCrop(height=CFG.SZ, width=CFG.SZ, p=1.0),
    A.Resize(CFG.SZ,CFG.SZ,p=1),
    A.Normalize(),
    ToTensorV2(),
])

# %% [markdown]
# ### Visualization

# %%
dataset_show = WadhwaniDataset(train_new, augs=TRAIN_AUG, mode='train')
loader_show = torch.utils.data.DataLoader(dataset_show, batch_size=6)
img,target,id = next(iter(loader_show))

grid = torchvision.utils.make_grid(img, normalize=True, padding=2)
grid = grid.permute(1, 2, 0)
show_image(grid, figsize=(15,8),title=[x for x in target.numpy()]);

# %% [markdown]
# ### Model

# %%
def get_wadhwani_classification_model(model_name, pretrained=True, **kwargs):
    model = timm.create_model(model_name, pretrained=pretrained, **kwargs)
    model = nn.Sequential(model, nn.Dropout(0.15), nn.Linear(model.num_classes, 2))
    return model

# %%
dl = DataLoader(WadhwaniDataset(train_new, augs=TRAIN_AUG, mode='train'),
                          batch_size=2,
                          shuffle=True,
                          num_workers=8,
                          drop_last=True,
                        worker_init_fn=worker_init_fn)

a,b,c = next(iter(dl))
a.shape,b[0].shape,b[1].shape
# Out:
# (torch.Size([2, 3, 1024, 1024]), torch.Size([2]), torch.Size([2]))

# %%
m = get_wadhwani_classification_model(CFG.MODEL)
out = m(a)
print(out, out.shape)
# Out:
# tensor([[ 0.1727, -0.0272],
#         [ 0.4036,  0.4106]], grad_fn=<AddmmBackward0>) torch.Size([2, 2])

# %%
 nn.BCEWithLogitsLoss()(out,b)
# Out:
# tensor(0.7285, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)

# %% [markdown]
# ### Train & Validation Function

# %%
def train_one_epoch(
    model: nn.Module,
    loader: Iterable,
    loss_fn: Callable,
    optimizer: torch.optim.Optimizer,
    lr_scheduler: torch.optim.lr_scheduler._LRScheduler = None,
    mixup_fn: Callable = None,
    grad_scaler: torch.cuda.amp.GradScaler = None,
    mbar: master_bar = None,
):

    model.train()

    losses_m = utils.AverageMeter()

    pbar = progress_bar(loader, parent=mbar, leave=False)
    pbar.update(0)

    for batch_idx, (input, target) in enumerate(loader):
        input, target = input.cuda(), target.cuda()
        
        optimizer.zero_grad()
        with torch.cuda.amp.autocast(enabled=True):
            output = model(input)
            loss = loss_fn(output, target)
            
        losses_m.update(loss.item(), input.size(0))

        grad_scaler.scale(loss).backward()
        grad_scaler.step(optimizer)
        grad_scaler.update()

        if lr_scheduler is not None:
            lr_scheduler.step()

        pbar.update(batch_idx + 1)
        pbar.comment = f"{losses_m.avg:.4f}"

    pbar.on_iter_end()
    return OrderedDict([("loss", losses_m.avg)])


@torch.inference_mode()
def validate(model: nn.Module, loader: Iterable, loss_fn: Callable, mbar: master_bar):
    model.eval()

    accs_m = utils.AverageMeter()
    losses_m = utils.AverageMeter()

    pbar = progress_bar(loader, parent=mbar, leave=False)
    pbar.update(0)

    for batch_idx, (input, target) in enumerate(loader):
        
        input, target = input.cuda(), target.cuda()
        output = torch.round(model(input))

        loss = loss_fn(output, target).item()
        losses_m.update(loss, input.size(0))

        acc = accuracy_multi(output, target).item()
        accs_m.update(acc, output.size(0))

        pbar.update(batch_idx + 1)

    pbar.on_iter_end()
    return OrderedDict([("loss", losses_m.avg), ("accuracy", accs_m.avg)])

# %% [markdown]
# ### Run!

# %%
def training_loop(fold):
    
#     if fold>0:
#         time.sleep(5*60)
    
    with IPyExperimentsPytorch(exp_enable=False, cl_set_seed=42, cl_compact=True):
        print()
        print("*" * 100)
        print(f"Training fold {fold}")
        print("*" * 100)

        torch.backends.cudnn.benchmark = True

        dataset_train = WadhwaniDataset(train_new.query("fold!=@fold").reset_index(drop=True), augs=TRAIN_AUG, mode="train")
        dataset_valid = WadhwaniDataset(train_new.query("fold==@fold").reset_index(drop=True), augs=VALID_AUG, mode="valid")

        print(f"TRAIN: {len(dataset_train)} | VALID: {len(dataset_valid)}")

        loader_train = torch.utils.data.DataLoader(dataset_train, CFG.BS, num_workers=8, shuffle=True, drop_last=True)
        loader_valid = torch.utils.data.DataLoader(dataset_valid, CFG.BS * 2, num_workers=8, shuffle=False)

        model = get_wadhwani_classification_model(CFG.MODEL, pretrained=True, drop_path_rate=0.15)
        model.cuda()
        # adamw
        optimizer = create_optimizer_v2(model, "lookahead_RAdam", lr=CFG.LR, weight_decay=CFG.WD, layer_decay=0.9)

        num_train_steps = len(loader_train) * CFG.EP
        lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, num_train_steps)

        train_loss_fn = nn.BCEWithLogitsLoss()
        valid_loss_fn = nn.BCEWithLogitsLoss()

        grad_scaler = torch.cuda.amp.GradScaler()

        print(f"Scheduled epochs: {CFG.EP}")

        mbar = master_bar(list(range(CFG.EP)))
        best_epoch, best_metric = 0, 0
        metric_names = ["epoch", "train_loss", "valid_loss", "accuracy", "time"]
        mbar.write([f"{l:.6f}" if isinstance(l, float) else str(l) for l in metric_names], table=True)

        for epoch in range(CFG.EP):
            start_time = time.time()
            mbar.update(epoch)

            train_metrics = train_one_epoch(
                model, loader_train, train_loss_fn, optimizer,
                lr_scheduler=lr_scheduler, mixup_fn=None, grad_scaler=grad_scaler, mbar=mbar)

            valid_metrics = validate(model, loader_valid, valid_loss_fn, mbar=mbar)
            
            elapsed = format_time(time.time() - start_time)
            epoch_log = [epoch,train_metrics["loss"], valid_metrics["loss"], valid_metrics["accuracy"], elapsed]
            mbar.write([f"{l:.6f}" if isinstance(l, float) else str(l) for l in epoch_log], table=True)

            if valid_metrics["accuracy"] > best_metric:
                best_epoch, best_metric = epoch, valid_metrics["accuracy"]
                dirpath = MODEL_FOLDER / (KERNEL_TYPE + f"_CV_{fold}.pth")
                if not CFG.debug:
                    torch.save(model.state_dict(), dirpath)

        mbar.on_iter_end()
        print("*** Best metric: {0} (epoch {1})".format(best_metric, best_epoch))

# %%
out = []
img = []

for fold in range(CFG.n_splits):
    dataset_valid = WadhwaniDataset(train_new.query("fold==@fold").reset_index(drop=True), augs=VALID_AUG, mode="valid")

    print(f"VALID: {len(dataset_valid)}")

    loader_valid = torch.utils.data.DataLoader(dataset_valid, 16, num_workers=8, shuffle=False)

    for input,label,id in tqdm(loader_valid, dynamic_ncols=True, desc="OOF"):
        with torch.cuda.amp.autocast(), torch.no_grad():
            input = input.cuda()
            model = get_wadhwani_classification_model(CFG.MODEL, pretrained=False)
            model.load_state_dict(torch.load(f'{MODEL_FOLDER}/tf_efficientnet_b2_ns_1024_bs16_ep10_lr0.005_wd1e08_CV_{fold}.pth'))
            model.eval()
            model.cuda()
            out.append(F.sigmoid(model(input)))
            img.append(id)
            
    torch.cuda.empty_cache()
# Out:
# VALID: 1418
# OOF:   0%|                                                                                       | 0/89 [00:00…
# VALID: 1416
# OOF:   0%|                                                                                       | 0/89 [00:00…
# VALID: 1411
# OOF:   0%|                                                                                       | 0/89 [00:00…
# VALID: 1417
# OOF:   0%|                                                                                       | 0/89 [00:00…
# VALID: 1417
# OOF:   0%|                                                                                       | 0/89 [00:00…

# %%
OOF_ids = list(sum(img, ()))
OOF_preds = torch.cat(out).cpu().numpy()

# %%
len(OOF_ids), len(OOF_preds),len(train_new)
# Out:
# (7079, 7079, 7079)

# %%
torch.cat(out).shape
# Out:
# torch.Size([7079, 2])

# %%
# ========================================
# INFERENCE LOOP
# ========================================

test_ds = WadhwaniDataset(test_df, augs=VALID_AUG, mode="test")
test_dl = torch.utils.data.DataLoader(test_ds, 16, num_workers=8, shuffle=False, pin_memory=True)
print('Test size: {}'.format(len(test_dl.dataset)))
    
test_preds = []
test_ids = []

for input in tqdm(test_dl, dynamic_ncols=True, desc="Predicting"):
    pred = []
    with torch.cuda.amp.autocast(), torch.no_grad():
        input = input.cuda()
        for fold in range(5):
            model = get_wadhwani_classification_model(CFG.MODEL, pretrained=False)
            model.load_state_dict(torch.load(f'{MODEL_FOLDER}/tf_efficientnet_b2_ns_1024_bs16_ep10_lr0.005_wd1e08_CV_{fold}.pth'))
            model.eval()
            model.cuda()
            pred.append(F.sigmoid(model(input)))
            torch.cuda.empty_cache()
            gc.collect()
    pred = torch.mean(torch.stack(pred, -1),-1).data.cpu().numpy()
    test_preds.append(pred)
    
test_preds = (np.concatenate(test_preds, axis=0))
# Out:
# Test size: 2803
# Predicting:   0%|                                                                               | 0/176 [00:00…

# %%
OOF_ids
# Out:
# ['id_0005ef295aafe6acc63587db.jpg',
#  'id_000b2e6c437c643f25d4a6c3.jpg',
#  'id_000c2040da4b05816cefbb96.jpg',
#  'id_00b6b77332b132dbb58a7dc4.jpg',
#  'id_00d5771ea3336b8bec3efadc.jpg',
#  'id_00e5892f475750f80a9f9ce5.jpg',
#  'id_00f6b4240b3a317a94ebe569.jpg',
#  'id_01605fca152d65489cea2825.jpg',
#  'id_01997137aca6c1bdf84b7987.jpg',
#  'id_020985f3f6038e28674b15a9.jpg',
#  'id_023bd295735a5e2c5ae0891b.jpg',
#  'id_024abaf8d48a4982a5508ee3.jpg',
#  'id_025d41d8ecbff4e781b3d36c.jpg',
#  'id_02662f5b5d921243e554a070.jpg',
#  'id_02735ccfc0a0da080b92142c.jpg',
#  'id_02aca55d9126de2b80f16312.jpg',
#  'id_02bbcd3cd6c6ce97988d056b.jpg',
#  'id_032036b2fe67aa36020d3e0e.jpg',
#  'id_03226e49708d83256b77d8c2.jpg',
#  'id_0336775a1070c8fff8ea6d63.jpg',
#  'id_03704061c6f52c0c7c8d9250.jpg',
#  'id_0379917b9694305f0886fbec.jpg',
#  'id_03b3f4b53f66dc3549b7e7ad.jpg',
#  'id_03cbbc4ac3d9c997511ce815.jpg',
#  'id_04290bf90bbe8300c0951e9b.jpg',
#  'id_04669402500c6f26e407d4d3.jpg',
#  'id_04680f3cec5e0338f55593ad.jpg',
#  'id_047a6bb3429597a9e0c38101.jpg',
#  'id_04a174960c942fe0d8882117.jpg',
#  'id_04eb9b2233908985b8293019.jpg',
#  'id_04f3c046496d4311e3093d0f.jpg',
#  'id_0508525a4d75cf399954cf20.jpg',
#  'id_050f3511dd7eba73b0fac029.jpg',
#  'id_0548330de2c8ece3b7dcc913.jpg',
#  'id_055390aa60ea7c3e339a9582.jpg',
#  'id_058e42a04ff92af25d8c21cf.jpg',
#  'id_05d179a507f719c3f20f41a2.jpg',
#  'id_05d4f58e57efa1b57f2e2547.jpg',
#  'id_062e4642ce581927e6c3fd92.jpg',
#  'id_065837a379642cde8166ea78.jpg',
#  'id_066abd53fbc0b372f8a64ae4.jpg',
#  'id_0688b751b8c86ba9f7afb295.jpg',
#  'id_0693406f6c747d0f7afff558.jpg',
#  'id_06ab2db324f0326daba63e3c.jpg',
#  'id_06d6e1fee70bdbb650806a12.jpg',
#  'id_0700019c27ecad7454154619.jpg',
#  'id_072ae1a9502d6080c7dea257.jpg',
#  'id_073fc953d51ad9a2a2082b60.jpg',
#  'id_0787cbdeac9b9f5c9b2c7b84.jpg',
#  'id_07ec3a38a82014b72a801cf4.jpg',
#  'id_07f0884fad6c5f017f5e2518.jpg',
#  'id_084ed17963f7b5f6b7c29546.jpg',
#  'id_0853979a71cd2903b979dddd.jpg',
#  'id_087be8cc57f505d53ac65e57.jpg',
#  'id_0881c2a752094471419a8b30.jpg',
#  'id_0884c2eda4012d5557088d3f.jpg',
#  'id_0897b02ebc37d105b4fddfca.jpg',
#  'id_089931a67e0ea4455bfc4f17.jpg',
#  'id_08a9c06cb7b912c6e8b07192.jpg',
#  'id_0937ec11e95773dfef2bcd3f.jpeg',
#  'id_09e136109c23b88b04eb8e29.jpg',
#  'id_09fae2e30db8824508588e09.jpg',
#  'id_0a5024e190deb6cc98bf193f.jpg',
#  'id_0a818265973a20d2b956f6aa.jpg',
#  'id_0ab798f3a41751093bbb1198.jpg',
#  'id_0afc4ada02586abc321f5d6a.jpg',
#  'id_0b09f74b99b382578316153b.jpg',
#  'id_0b0bb2e548c125a603604c47.jpg',
#  'id_0b1dacd3d306bd90d4c31bb1.jpg',
#  'id_0b3d575138b4851a6fd80fd8.jpg',
#  'id_0b60a4f1868ca6a2da3e4d74.jpg',
#  'id_0b62c9a19ba8d68071bf1461.jpg',
#  'id_0ba3b66e701791d929a49e18.jpg',
#  'id_0bc8486c0b70e1cc60814d12.jpg',
#  'id_0c329af17cb7db04ac2d685f.jpg',
#  'id_0ca06cb90c10eacabd544011.jpg',
#  'id_0cc46ffd02250c5908ea8c7f.jpg',
#  'id_0cf6705263e4be9eb5218b09.jpg',
#  'id_0d261051a3620f6f78e8edea.jpg',
#  'id_0d9fc5ae642a23d963120ee0.jpg',
#  'id_0dac6a94a42716a18c4fb212.jpg',
#  'id_0dcdd870c4992fc4751490a2.jpg',
#  'id_0def9094f78db8962ac5f131.jpg',
#  'id_0df0b6fd59219a3610ec3c8b.jpg',
#  'id_0e014ae2f50a98b8e96c3de8.jpg',
#  'id_2173f6b57f7f145168e0e97d.jpg',
#  'id_21a55fbdaff7a31c6e66d09a.jpg',
#  'id_21ecffdfbbdc4f558a015901.jpg',
#  'id_21fdf37aabf35a2c0e4aa7f2.jpg',
#  'id_221afb9cc1c52d6ffddf1e5b.jpg',
#  'id_223b6490f5bc530e1a8792e3.jpg',
#  'id_226844956924236d4f83614c.jpg',
#  'id_22a36dae9a130ff5d7751e93.jpg',
#  'id_22cc093b7ba5adfc0573ed62.jpg',
#  'id_22e5ef5e0e3d9f629f8b1429.jpg',
#  'id_22f4a54469b51e21494312cd.jpg',
#  'id_23135a7965c424816c85f3b6.jpg',
#  'id_2353c3d549d4f8b7db19866a.jpg',
#  'id_23d5a7a3c44f9aa7026b85cd.jpg',
#  'id_240afffddbc08a6b93c73dc2.jpg',
#  'id_2443f5636b4e9934af21a07e.jpg',
#  'id_246699c13d239db5905dec84.jpg',
#  'id_2484969b26203beacb1b8009.jpg',
#  'id_2484cae670666726d555dc6a.jpg',
#  'id_249a5c9a1754c638ca114e7e.jpg',
#  'id_24a23f2b10e8fe1ab1ebd1d8.jpg',
#  'id_24b449d6cf6829396c5ed3b0.jpg',
#  'id_24b7029eb03be65db0a6aaef.jpg',
#  'id_24c7d7d92b45930361f0d855.jpg',
#  'id_24cee4cca4dfe27f1c040225.jpg',
#  'id_24f5a32c266c2029a8b9d43b.jpg',
#  'id_25985218b19a913d1dafeb1a.jpg',
#  'id_25b34b4e1e60df02056ee729.jpg',
#  'id_25b619ca364f4e684368940b.jpg',
#  'id_25c300981b56ef02aeee20a6.jpg',
#  'id_25d7f50d6bf836fc57080fc0.jpg',
#  'id_25fdb32b83d55b1efff0b0bb.jpg',
#  'id_26abdaff1a71e53f2eff4629.jpg',
#  'id_274a7383e57fca717733f2af.jpg',
#  'id_276eeb17a8eacce57ebea9ff.jpg',
#  'id_27a1c4cf0978851380a011c5.jpg',
#  'id_27f11d155617cd399e9aa66f.jpg',
#  'id_27fa833de2d8b54e64fddab3.jpg',
#  'id_283f4c5a71351d7e40fce538.jpg',
#  'id_2859b8953f18a44bd6fe29df.jpg',
#  'id_28654daa14cb91260c674a8f.jpg',
#  'id_28a57b06ad3a0b595c03f8dc.jpg',
#  'id_28cf1aee1e763bfd602fa77e.jpg',
#  'id_2939a44eb09798540c8ed019.jpg',
#  'id_2950c9c952f5d41d4e314772.jpg',
#  'id_2996b8dc046630210f7497d6.jpg',
#  'id_2a40ee344dedd6ff1c304af4.jpg',
#  'id_2a4e97feef5d731ee240ae3b.jpg',
#  'id_2acca0f58a00ef4113e5efa4.jpg',
#  'id_2afa15f479dd8e6e7d35cc48.jpg',
#  'id_2b04aea4eb21f6b349d2dc18.jpg',
#  'id_2b56963bd1cff875fa29b4d0.jpg',
#  'id_2baa68c3a468d64e2e148833.jpg',
#  'id_2bc3b2cd2ced1e4cc728bb86.jpg',
#  'id_2c13831e4f69057f3be1fcbd.jpg',
#  'id_2c2aa6d43fee3dd868087e99.jpg',
#  'id_2ca0601e65da8efe3bc620b9.jpg',
#  'id_2cb756e80948152b43afd6ea.jpg',
#  'id_2ccb530c810ac01c05dd5543.jpg',
#  'id_2ce3192913a2732669bc8021.jpg',
#  'id_2d1d2b4494fe6bf255c3aa28.jpg',
#  'id_2d314ea31ed2d1e5fc90c2ed.jpg',
#  'id_2d4dbca26a62d83c73b170e0.jpg',
#  'id_2d6e1df45fc98806d6f3c6bd.jpg',
#  'id_2dee1137f0e2c8e2142bb298.jpg',
#  'id_2e45072efa7ad1b9cee45f49.jpg',
#  'id_2e59a2a183e19d979ca9c452.jpg',
#  'id_2e660eb60913d1645738eca5.jpg',
#  'id_2ef30678588de068c38bdc7e.jpg',
#  'id_2ef53ea26192723abd019459.jpg',
#  'id_2efabe2a0a383170cd38b070.jpg',
#  'id_2f162218a3c7d69ffbe205f5.jpg',
#  'id_2f2eb2f16e50503d71041d1f.jpg',
#  'id_2f4fed3097b4f2b10dc3aff2.jpg',
#  'id_2f6d43f7b80ea7e39ad9a895.jpg',
#  'id_2fdb6ace4bac964aca07f8e5.jpg',
#  'id_2ff6c412bfa93fb628d4bcf2.jpg',
#  'id_30479d6e536e3a5375333437.jpg',
#  'id_304f0032d02d0c351d6000c7.jpg',
#  'id_30671a08d8c2eb1aefdf3ee0.jpg',
#  'id_3090170ec6a46066dd04a7a0.jpg',
#  'id_30e1a82f8103acebe8fa7320.jpg',
#  'id_313e117de765989f2e3602c0.jpg',
#  'id_3154d86b5712028196b33308.jpg',
#  'id_3157d58b3b01847a4f46c046.jpg',
#  'id_31619327473866aac8f6af1d.jpg',
#  'id_31ddb657337df8da42102b22.jpg',
#  'id_320ba71a25934e46c46b717e.jpg',
#  'id_326be1a2801d1845403b868d.jpg',
#  'id_3293fcba4f4791b3c583fd01.jpg',
#  'id_32968ec6bbfaa6f804998c7c.jpg',
#  'id_32d8663424dff339c1ad74e6.jpg',
#  'id_330521f25f0d8957ff875e83.jpg',
#  'id_330e346cefc4af8edf40e320.jpg',
#  'id_331a5666aca38247092373be.jpg',
#  'id_33213cb55b92a6f9ed2b65ea.jpg',
#  'id_335e73fc4a9d89b6702b4ef0.jpg',
#  'id_3362b4ac44a0522ec65460fe.jpg',
#  'id_33a529fa5885eab079ae4510.jpg',
#  'id_33c8fa97199fe4ae14f98cf1.jpg',
#  'id_33e55df6982ecfa4b53ec1cc.jpg',
#  'id_33f6b5f0e1bb9093722e582f.jpg',
#  'id_3448e29a33edb01052610183.jpg',
#  'id_344a5e36f173192dfac7bb9e.jpg',
#  'id_34688be98a1b7b532d8aec92.jpg',
#  'id_3469cef31d4e7c9c5ff008f5.jpg',
#  'id_3485f36f022d8546ee637c40.jpg',
#  'id_34d3c656726669086cd679de.jpg',
#  'id_34db8ad84a63a4d81c7ded1c.jpg',
#  'id_34f040fa8d61eb6e1b7b28d1.jpg',
#  'id_34fc16841a60daf5faf29e18.jpg',
#  'id_35581fd5d89a98e82fd04270.jpg',
#  'id_35823c15fa57b1b27654c164.jpg',
#  'id_360dc2aac038c28295fad700.jpg',
#  'id_36434014866aa28a8ee319dd.jpg',
#  'id_366c1ca75a0d0f79b5879fea.jpg',
#  'id_36769e1b615d09dd99518b7e.jpg',
#  'id_3681605948cea745e64cccbc.jpg',
#  'id_368b928fb43eb71786b5a849.jpg',
#  'id_36c14ed6bac7e07aa2252fd4.jpg',
#  'id_36cd58de8f5d74c7ff96cc79.jpg',
#  'id_36ef1845137730561df025fc.jpg',
#  'id_372407aadf0d30360f5650ac.jpg',
#  'id_37403c50eb388f0f88aa540c.jpg',
#  'id_374bfc6701249bfd12c7316b.jpg',
#  'id_37b18eeab8abb914093b2f50.jpg',
#  'id_37f0e23f1b0a7dca67ef16a7.jpg',
#  'id_380af6aae5b4e1855c0de63f.jpg',
#  'id_380b3a79ec8bb4e9efd1bcd8.jpg',
#  'id_380bcfcd7dab646b3d48916a.jpg',
#  'id_385141a29df88072c857c7ac.jpg',
#  'id_385ab183e8a86f7c3a8b5f19.jpg',
#  'id_38841cbbc867d0a77a6b0ce3.jpg',
#  'id_38a3e5f735025c6352cbc785.jpg',
#  'id_38d6c45c103db332783263df.jpg',
#  'id_38e0ccb191ecf678df0899d2.jpg',
#  'id_38fec0430a7e8ad1436c792b.jpg',
#  'id_39602f4481be25b4af6b6b8c.jpg',
#  'id_39855967cd12985d3c65e778.jpg',
#  'id_398a62c94ee8c1306d7760f8.jpg',
#  'id_399afa50d33a391d07c664e5.jpg',
#  'id_39ec659396fc64ec589db2aa.jpg',
#  'id_3a2cc54f5e7cfdb9505325ab.jpg',
#  'id_3a44fdf70d7b284a1277283d.jpg',
#  'id_3a70ed45afbbb4f9faf84461.jpg',
#  'id_3aa58ece5abe5e95d42029db.jpg',
#  'id_3ae99e22c8192c01e03795b6.jpg',
#  'id_3b20da9c44eb3f3b134e98e3.jpg',
#  'id_3b4702c75cf3f9da8c2874f6.jpg',
#  'id_3b8c8d2f705a56aeb58802c8.jpg',
#  'id_3ba876e782e7d7c6acc935ad.jpg',
#  'id_3ba8dc63b4c36114ad844672.jpg',
#  'id_3bef6df769a84abc06179572.jpg',
#  'id_3c14c3b40ef5470373662086.jpg',
#  'id_3c1d9063db41138b1f41dc8b.jpg',
#  'id_3c2e9b830fe46213c575830c.jpg',
#  'id_3c549fa3babb085f600a3354.jpg',
#  'id_3c6bc7b2821cb9209d83f264.jpg',
#  'id_3cab0372a828aaeeeb4fed88.jpg',
#  'id_3ccc249d56051088043fc07c.jpg',
#  'id_3d529447e7cf2909bccf7558.jpg',
#  'id_3d55a92be019939bbc59958d.jpg',
#  'id_3d6603aa6290730db1899902.jpg',
#  'id_3d8e45c4352897ed6603098c.jpg',
#  'id_3d973fa4e3f0c7be72efcd7c.jpg',
#  'id_3da20b1029c007132609333b.jpg',
#  'id_3db54a72cd86c43dcd363261.jpg',
#  'id_3dc401986322afe86d6605a0.jpg',
#  'id_3ddac857d45b7eb82bb90519.jpg',
#  'id_3de46127b4d124f518f89b9b.jpg',
#  'id_3e009efd254f3e879a54c9c1.jpg',
#  'id_3f1502c4710a94f6b8ffcc5d.jpg',
#  'id_3f587e4b92a84d611f298bc0.jpg',
#  'id_3f5ea6a102371f3a262b638a.jpg',
#  'id_3f803dd8d69cff136ae40efd.jpg',
#  'id_3f8373d05ad78be32b959f57.jpg',
#  'id_3f9a324349e6c6afade453a0.jpg',
#  'id_3ff37d1ec4ca458fbd21306b.jpg',
#  'id_3ff5647f78c6f85c598ca864.jpg',
#  'id_400ea678601d8c2ed2660e4c.jpg',
#  'id_403e8f41f0f17ba90a5a387b.jpg',
#  'id_409826b70827915e26f8d5b9.jpg',
#  'id_40d61d1122e6c4e808f06bd1.jpg',
#  'id_40eab242e92bf7cc453187be.jpg',
#  'id_410071fed320aadf3fbc9b13.jpg',
#  'id_415954c0b5f3493a6f7e1850.jpg',
#  'id_415b3ac211e7012067111426.jpg',
#  'id_416387d40757f90b5076ea26.jpg',
#  'id_4213d8cebee5e4f64c318f23.jpg',
#  'id_4246dafe6c2650e98088adac.jpg',
#  'id_4273ad2076d5a0679b572142.jpg',
#  'id_42ec5c6e47f04742017512c4.jpg',
#  'id_430dec6ba16f88d39f06e60d.jpg',
#  'id_437b6bd75cf41a7e411d9526.jpg',
#  'id_43829c4cb8ab49623b1e3699.jpg',
#  'id_438fe07992797992a3467c7d.jpg',
#  'id_444be4354f56ce51e61ce071.jpg',
#  'id_4480bcf1a94358a0278bfea9.jpg',
#  'id_44e2d3dac93c00d9f12e6c61.jpg',
#  'id_4502460e2475deb19ba2a822.jpg',
#  'id_450ab68ba8337046201f5ad0.jpg',
#  'id_4515b2ba0123ab96b9d4c7f7.jpg',
#  'id_453b5e7ee5477fd9795afaae.jpg',
#  'id_458ce56b1fbca2ef9df93ac7.jpg',
#  'id_459ab5bc6f3a7da4bea2e00e.jpg',
#  'id_45c154b3769ee05b841a465a.jpg',
#  'id_4640b60ce3fa050bde088cf0.jpg',
#  'id_465a14ce2baafe29b0abbbb8.jpg',
#  'id_46ae806051fccf86d9bcd94e.jpg',
#  'id_46bae1f34818e6a157eec564.jpg',
#  'id_46d20bd8bf8c803ec30d2949.jpg',
#  'id_46fcd8a3ae37ec1880d8d77b.jpg',
#  'id_4717be869bebbc7fc3054187.jpg',
#  'id_471b9b1901cc8a40f25126c0.jpg',
#  'id_480149601cdfd450f380ee48.jpg',
#  'id_4815804074226d2a2d540145.jpg',
#  'id_48446fd539d87dfd6eec320c.jpg',
#  'id_486e35843f023689f015d255.jpg',
#  'id_489814a82c2045cfa2b60fe5.jpg',
#  'id_48fc1e4c750139c447a607ec.jpg',
#  'id_49895e52f11b1600346468a2.jpg',
#  'id_49c4a6e4908dca879a3b95fc.jpg',
#  'id_49e770aee961370207b75170.jpg',
#  'id_49e9d8499bfc29cd2d1d2b9d.jpg',
#  'id_49efc4fa4008038e5c5cbb6e.jpg',
#  'id_4a5b8a7fcb442086079fb929.jpg',
#  'id_4a60316fed508fa57537d679.jpg',
#  'id_4aa55f79df685192709cce8a.jpg',
#  'id_4ab3f0f6b17ae960a2c2cc7d.jpg',
#  'id_4acf5f7dc68566b163366d66.jpg',
#  'id_4b2648cb8d2ee3292fb9c2e6.jpg',
#  'id_5677814e2e9096c676de84bc.jpg',
#  'id_568490fe178c251439082fbc.jpg',
#  'id_569cb465b2429a71a98d47dc.jpg',
#  'id_56a69741caa331a918acb290.jpg',
#  'id_56c69ab467d3e7aacc4a3ed0.jpg',
#  'id_56d378cac63c92a0545c66e0.jpg',
#  'id_56e885c7dda3e4652bb35ebb.jpg',
#  'id_56ec62c8a8033dd57e69852d.jpg',
#  'id_57183220c4cea97550e1131a.jpg',
#  'id_572c6960f4b247a41476d1a8.jpg',
#  'id_57590c1122a12db61072c081.jpg',
#  'id_577a7d77490891cb48211c41.jpg',
#  'id_580d9920cf10efc929f4a9d3.jpg',
#  'id_585749c3e19ffd223b199ae7.jpg',
#  'id_58a60c5cfb6de63ebc0b35d6.jpg',
#  'id_58e04555038135a9d8b75bbf.jpg',
#  'id_58fa72c160dc70ab92c2c2a9.jpg',
#  'id_590068f0585ba7d354c64f13.jpg',
#  'id_59014b48baab3c64f604306a.jpg',
#  'id_595193111aa89113a6665e2d.jpg',
#  'id_59e39f7357f4f7537d024ae9.jpg',
#  'id_59ec4830c86c9b405fbb1f2e.jpg',
#  'id_59f0eff262e799e7091d7c00.jpg',
#  'id_59f70fcce3817fa7c94846a6.jpg',
#  'id_5a0694ce8fa48e0748b09762.jpg',
#  'id_5a18fce6432f8e1af2ba0ca0.jpg',
#  'id_5a38e05ce5123eff1bfc5c42.jpg',
#  'id_5a68ff6ecf13fc3e3549fe17.jpg',
#  'id_5ac30f5794a77e94f5d09d01.jpg',
#  'id_5adfb6790540fbb8e839ba7e.jpg',
#  'id_5c051b77181bdba141bde593.jpg',
#  'id_5c0b9358657c5c0eec1c4ca0.jpg',
#  'id_5c10b74583b97f420882e3b3.jpg',
#  'id_5c88fc704e1f0b774b53e61a.jpg',
#  'id_5cb392aefe19e53639bae37e.jpg',
#  'id_5cb69d80ae383b47434783eb.jpg',
#  'id_5ccabd8145148ae5cd746603.jpg',
#  'id_5cd74cadb84fa53dff371611.jpg',
#  'id_5d2c0b596f7ae20815064b41.jpg',
#  'id_5d5f2a0d0ab279e86a3ddcb5.jpg',
#  'id_5d62d2212fe9b8c97c1b89aa.jpg',
#  'id_5dc80cbb1295dfdce404e410.jpg',
#  'id_5e0bfa9dd2a210b680c353dd.jpg',
#  'id_5e7f0ba8bd686c76e87bb708.jpg',
#  'id_5eb69e3b0d78ea79d667ff85.jpg',
#  'id_5eca9072a873bf4ff9a3d687.jpg',
#  'id_5f09b9a79329793cef1d9508.jpg',
#  'id_5f57ede164fcc9b3c218cbb1.jpg',
#  'id_5f808541d8434fa9d7f81d0c.jpg',
#  'id_5fc99d7956efaed6dd11d357.jpg',
#  'id_5ffc8136f4451bf63a7242c1.jpg',
#  'id_6004c176d50c996c2d3b6bf0.jpg',
#  'id_600726392a63e3077df39db4.jpg',
#  'id_6039710b95e3359cb1dd3c29.jpg',
#  'id_60766a67e505da1013fc848d.jpg',
#  'id_61226cfb15d0c98a679b2a7c.jpg',
#  'id_612e6de9c0601717dc05e766.jpg',
#  'id_617aa13c8536214efa124915.jpg',
#  'id_61a647392571dd89351e431d.jpg',
#  'id_61e329f961001c4dff267ed9.jpg',
#  'id_6289307020d80223faa40cc3.jpg',
#  'id_629107cce19d4eec35440023.jpg',
#  'id_62ad46016ef75e775e5a512b.jpg',
#  'id_62bf534ea6b954996df2138e.jpg',
#  'id_62cdc5834b5701e0a9879dcc.jpg',
#  'id_6328684d922e36aeb9578a47.jpg',
#  'id_6331ea45b46347f97f682bd7.jpg',
#  'id_6354befdda8e7a86c824b4e1.jpg',
#  'id_63ea99471588698a9ffa5824.jpg',
#  'id_642249d26bf7e91be8a62ecb.jpg',
#  'id_6425d3151e49698d4cc6c46c.jpg',
#  'id_64355bb8c50c7226b7ae4de3.jpg',
#  'id_643d670d010dc92f2204b739.jpg',
#  'id_6456f788039726eaf6c110b8.jpg',
#  'id_64c1bc1a108f3074070b71d3.jpg',
#  'id_64c848c06e75bae16dac3e9d.jpg',
#  'id_64cc98ca32c55449e6a0e173.jpg',
#  'id_64fa79d405890427d696b72c.jpg',
#  'id_65241aa3f5db03c1613e89a6.jpg',
#  'id_653b64f92a1bcadd53b1dadb.jpg',
#  'id_653f80ad9c5cb3d0d4523b2c.jpg',
#  'id_65b4b70d88cdca19f8bb1f75.jpg',
#  'id_65ec5f71b2121c63586afca3.jpg',
#  'id_65fd469716bea176b5074b65.jpg',
#  'id_664240b3972a415e7fceca90.jpg',
#  'id_66457544282031e949d217c5.jpg',
#  'id_6653254b6db2bf6265c71486.jpg',
#  'id_667aed865e4992c3ab794e97.jpg',
#  'id_670518c97b8679d16fa7c5c0.jpg',
#  'id_67089ebd8ce447263971b3ec.jpg',
#  'id_672eda052aa637457b570df0.jpg',
#  'id_6758011c60bd46af52e7f3bf.jpg',
#  'id_67a21bbbb5dbcf7df3750331.jpg',
#  'id_67ab2b6076107b9898e6af57.jpg',
#  'id_67c4147b3047cd8d1f214636.jpg',
#  'id_68002d9714d9d4cd3d00acd0.jpg',
#  'id_68114a04a0a0f8856d6cf37a.jpg',
#  'id_681a947d03d09ea387f12203.jpg',
#  'id_683354888bffdb3ef0cbb8b7.jpg',
#  'id_685b3cc8dcde6062f8c73ad4.jpg',
#  'id_687545070a6f40462ce9c03a.jpg',
#  'id_68a618fe3572aca2cee37231.jpg',
#  'id_68d41dae1687aab610107b62.jpg',
#  'id_68eb480c5faf1414a23b2620.jpg',
#  'id_6908b7482dd56bffc982660d.jpg',
#  'id_69554a303e0e411e1a6d0584.jpg',
#  'id_696f3b2106acf1bebff87121.jpg',
#  'id_699ca9cc1c6bb8b162f96c0d.jpg',
#  'id_69a861d998ce7dd2f270a169.jpg',
#  'id_69c3d0238e16483e970808bb.jpg',
#  'id_69e501485a9c65592542086c.jpg',
#  'id_6a0005e92615168fff59f68f.jpg',
#  'id_6a3b4c2d2a5903c85d56fef8.jpg',
#  'id_6a5dce4d6f431be06101c8f8.jpg',
#  'id_6a6674ac6f2c75b78fd75c7f.jpg',
#  'id_6a71f8b9bcc061d00120b59d.jpg',
#  'id_6aad9258b7e9f4914af2e5a8.jpg',
#  'id_76fe10415ca1944f0d2c6fbc.jpg',
#  'id_773220a5a4da9c9fb3184133.jpg',
#  'id_774e57956a9b6e529d6a4ff9.jpg',
#  'id_77f6e43b0956e2687619ae42.jpg',
#  'id_77fdca8563bb253d779aed7f.jpg',
#  'id_78204b8c791881f9832261c9.jpg',
#  'id_788d71443f593316c230dabf.jpg',
#  'id_78ec99127fc99e1fa6447905.jpg',
#  'id_79315b16208c06fe320dc379.jpg',
#  'id_7953de4d6771b2e869c6d654.jpg',
#  'id_795929bbf8e4044ec1f86d28.jpg',
#  'id_797f29d5dcc3d34c36d48ab4.jpg',
#  'id_799c5ca7511d761853b427be.jpg',
#  'id_79a220cca28a09bbca2424a5.jpg',
#  'id_79dcd2ecd1c7b86bae9eda0b.jpg',
#  'id_7a63cab223b908e68044525b.jpg',
#  'id_7a7a1b4f9726baea79764e80.jpg',
#  'id_7a8e0fb3e4ddcde05b4b0e1c.jpg',
#  'id_7b3abb9a51f272349ab44580.jpg',
#  'id_7bb371a624f909f6aad6026e.jpg',
#  'id_7c193433947c46d2da320ea6.jpg',
#  'id_7c3577018089fc59e1a0c86a.jpg',
#  'id_7c56e03f9cda8667e124fb12.jpg',
#  'id_7c6f18642ce2f9ce2bd8fc45.jpg',
#  'id_7c802717a92c1bd9f2fcae13.jpg',
#  'id_7c91bc6b8734d041a873dd97.jpg',
#  'id_7c9b65603acc8997a3ac9a1b.jpg',
#  'id_7cbcd9eb4e5e42aaa8e08eea.jpg',
#  'id_7d1a0ac808df431bd134539e.jpg',
#  'id_7d363a90e393dcb125e3e3c3.jpg',
#  'id_7d4cfe93d9dcf075fbfca76e.jpg',
#  'id_7db5bd7cf0ef5b3a0aa82652.jpg',
#  'id_7dc59bdfc3d910af8965b0a9.jpg',
#  'id_7de52051677c2c1aed382e3b.jpg',
#  'id_7df33f3c600f3dc5d49a406b.jpg',
#  'id_7e5904cf683a8f75e761dff4.jpg',
#  'id_7e6c948393d81c46885e8fb3.jpg',
#  'id_7ed72012edca8f47a84d8c37.jpg',
#  'id_7edd9c329f399271aa23d921.jpg',
#  'id_7f18f43ca59c47024dd7e561.jpg',
#  'id_7f59a4a3accd124956662f4d.jpg',
#  'id_7f6198d080c64d36ed5b0769.jpg',
#  'id_7f85922f5dcf720439fcacf0.jpg',
#  'id_7fad43a6e2a3efe8c1d2517c.jpg',
#  'id_7fe815905271d8b8ef97159a.jpg',
#  'id_7ffbb96fe23ae1259f2e7564.jpg',
#  'id_80867c5944474a6331a014f7.jpg',
#  'id_808750e35e9e35389b1bec92.jpg',
#  'id_8097dadc4cfa3935eb5f7128.jpg',
#  'id_80b0f1d3f53a1525d8786611.jpg',
#  'id_80e36e91c50c1ac42fdeb2e8.jpg',
#  'id_81040c1d3006c34b3658351a.jpg',
#  'id_815a853e1f9f5ff87218f668.jpg',
#  'id_81df7fb3575c11fe7df27f46.jpg',
#  'id_81f6b61c02ebc4bae404c86e.jpg',
#  'id_82358d3f207378c298be662e.jpg',
#  'id_82a347afacc97bce70a80b2a.jpg',
#  'id_8d2e3af86297196a327bb94a.jpg',
#  'id_8d40a6741a22889fb28d76e6.jpg',
#  'id_8d41141f1c345713ed7b4ae5.jpg',
#  'id_8d54092d3a4fc30da872b799.jpg',
#  'id_8d55cd448cfe423f546d4c0b.jpg',
#  'id_8d5db6640aa6ce8caa486047.jpg',
#  'id_8d7b3842ac5148570b056c90.jpg',
#  'id_8d80da44a45bdd14a1a9f19f.jpg',
#  'id_8e0a9c5c796e99cf73a96cef.jpg',
#  'id_8e72c501f73bd2ae30589c98.jpg',
#  'id_8e889ebbdeeaf884265eee26.jpg',
#  'id_8ee030ce063066b33eec9ff5.jpg',
#  'id_8eef9d001a2e83bb63086f46.jpg',
#  'id_8f24ecdd2c051d61b74928ce.jpg',
#  'id_8f66ce26dba5d36faa31f55a.jpg',
#  'id_8f6e338b7631f5b1f3e4399c.jpg',
#  'id_8f90e53fab715fd812ecd59e.jpg',
#  'id_8fad7b79fdf61f325d01e425.jpg',
#  'id_8fb958e8e2b59a547d055101.jpg',
#  'id_901366b422d48985af80dc0d.jpg',
#  'id_90155a6f76f49cf7b88a1b6f.jpg',
#  'id_90b2d47cb5d3feb24180f0ab.jpg',
#  'id_91057464907892fb3f25fb1b.jpg',
#  'id_9129c51f29f160d52e067d70.jpg',
#  'id_9141de8788e1070bace39305.jpg',
#  'id_9153d6eb1fbadaa386ccc8a3.jpg',
#  'id_9161f5d01e4c4dc491bd3e19.jpg',
#  'id_917bc59d07f58ed8edcdeef1.jpg',
#  'id_91d08ae819a47bfe552e23af.jpg',
#  'id_91e09a0cb182c02cc2b6a0a5.jpg',
#  'id_91f558fbfaf2e951b9569407.jpg',
#  'id_9235790c4fb0ffc766147cad.jpg',
#  'id_927ba0aaf4e065189ae53b81.jpg',
#  'id_927ccd731110807f33daa9ef.jpg',
#  'id_9291a4c88c6828c91ccd5e56.jpg',
#  'id_92e09f45006ea900f3eb50bf.jpg',
#  'id_92eac432a27554506ff201b6.jpg',
#  'id_92f7f4c43bd1dd3bd4e4cf4d.jpg',
#  'id_93764d403c5860863af1687d.jpg',
#  'id_93a380abab2326c0449b0cbc.jpg',
#  'id_93f8a3b0af4231997e7b525e.jpg',
#  'id_945fdd40f0bc78afa10bdc15.jpg',
#  'id_947693d3d4fb3202f48a734b.jpg',
#  'id_94826aedeed435d182bd7b3e.jpg',
#  'id_948a5a268cececa01c304f24.jpg',
#  'id_94a80a5183b3086b13f41514.jpg',
#  'id_94b119ad407ccf50aef02eef.jpg',
#  'id_94b1db54a31f5db537f8f441.jpg',
#  'id_94d1be737bc6f47e9bb0076c.jpg',
#  'id_94dacf53d6f0fb2e5b939573.jpg',
#  'id_94edd152d56dd49cc9f2ed09.jpg',
#  'id_94f17a85f41b316c01622d0c.jpg',
#  'id_94f968600367562613383914.jpg',
#  'id_95056b7191cdc0b534f7ea18.jpg',
#  'id_951a20708bdb0b7279dd6642.jpg',
#  'id_952286c3d0b0a908a78917ed.jpg',
#  'id_955ed3c2f411c729c8834715.jpg',
#  'id_a01da526c6763b78235560a3.jpg',
#  'id_a057e6f758dea296d19c9def.jpg',
#  'id_a073ac17ab1b4dab599f9ae6.jpg',
#  'id_a087ac9da415322854aa7223.jpg',
#  'id_a09107de226405384188350a.jpg',
#  'id_a0ce9b7876b03520835c1b8b.jpg',
#  'id_a157a54290c24a0bbe3e485f.jpg',
#  'id_a15b7f226584f737ced8bbad.jpg',
#  'id_a1ad987cf3450e2d0706ca25.jpg',
#  'id_a1d5df4045de4aeb817e3e99.jpg',
#  'id_a1e0954aee7954f0e29eaf80.jpg',
#  'id_a1ef5536ff2a3bc9c1f141ee.jpg',
#  'id_a1f56239a3459f8ef1a071f9.jpg',
#  'id_a205df71630210fb483cd1d7.jpg',
#  'id_a20dbc1cf55682111dd1b436.jpg',
#  'id_a214563ac6acda20be9c625f.jpg',
#  'id_a2a2a2595cf26cfd116539fe.jpg',
#  'id_a2a7a768d6ec06742f553e34.jpg',
#  'id_a2a86295daab1e0fa0c711f2.jpg',
#  'id_a2ce0282b494376cd8eec1bb.jpg',
#  'id_a2d1c7d5311fa5ac684d31fc.jpg',
#  'id_a2d744c848968b360b4f8110.jpg',
#  'id_a3ab26db223ff3a0c4f17b23.jpg',
#  'id_a3bfccc45269a8c4be3f61a8.jpg',
#  'id_a3bfeedfcc43c63dc008e7b3.jpg',
#  'id_a3c30cfbdf15f39402bc827f.jpg',
#  'id_a415e10c69c92e1600241f0e.jpg',
#  'id_a41782e2a0fbfcf9ba540116.jpg',
#  'id_a46c8b88785fbb90c7cee40d.jpg',
#  'id_a4718f9ff78a231f017cd83f.jpg',
#  'id_a499b9ae3d26c7b6acf0a9dc.jpg',
#  'id_a4d6505e2c667e999fd80177.jpg',
#  'id_a4d7b490fd1e75b496c3509d.jpg',
#  'id_a4e90df87938c54244cd37d1.jpg',
#  'id_a5036f2cccce4057c438ef18.jpg',
#  'id_a505e35a14ee36cba6100889.jpg',
#  'id_a51ef614c28d8d855f634672.jpg',
#  'id_a525ed614e4d5598d8c0b1af.jpg',
#  'id_a613881128daec4d29ba9577.jpg',
#  'id_a6544c01c813167781af5e69.jpg',
#  'id_a694acbb50ff170e93c69bde.jpg',
#  'id_a6a028629a72d06189e2c03e.jpg',
#  'id_a6adf2bae14b3126eb106bad.jpg',
#  'id_a6ca8c02206cabb1ed11260f.jpg',
#  'id_a6ef60db9fbe63e853ef69e3.jpg',
#  'id_a6f6e1a123639e61aa95d855.jpg',
#  'id_a6f8b4682091992f016f3e80.jpg',
#  'id_a7649b934a147a930230fe60.jpg',
#  'id_a76fc86b482d2fff19deef70.jpg',
#  'id_a796304386c7fa31ccfe3b07.jpg',
#  'id_a7a4161ca9edf7e764b4b52c.jpg',
#  'id_a7b950db58e56849a171db4c.jpg',
#  'id_a81ae674e4827f64a4c81441.jpg',
#  'id_a83b2d3cb8fcfdc279e02aa8.jpg',
#  'id_a84a5b05cd34f05f179d2941.jpg',
#  'id_a8564f755977a8504176dbbb.jpg',
#  'id_a8f24688ea194fb0fdba2851.jpg',
#  'id_a907bfd4b29770865b717851.jpg',
#  'id_a9ae86b91b88f25c1d57bffa.jpg',
#  'id_a9e6bb7ad476a7438fc829ae.jpg',
#  'id_a9e841ba17d820e16a79ddc5.jpg',
#  'id_aa80ee81b4084bf92dd241eb.jpg',
#  'id_aa8d3d71bbc48c762e8daf01.jpg',
#  'id_aaa1107b10fdc69137f21998.jpg',
#  'id_aafecef131c9df156bc3565f.jpg',
#  'id_ab3904192fe0d21a6c33f459.jpg',
#  'id_ab3f900f8086301c83a2262c.jpg',
#  'id_ab549908c19a90a54d6852e8.jpg',
#  'id_ab65a4615199450dc459a3ff.jpg',
#  'id_abd3bbdc438a7984f19a3bc7.jpg',
#  'id_abdf3e7c5b3962dfe2e9bccc.jpg',
#  'id_ac42c3c99a7183dd39f37c54.jpg',
#  'id_ac482b0d84462517031bac5c.jpg',
#  'id_ac732368115c3dff4b7cc28d.jpg',
#  'id_ac82344c7efc9c4678d9a129.jpg',
#  'id_ac8832ee2f171388ce625d34.jpg',
#  'id_aca2014f1618620c37b84117.jpg',
#  'id_ace75ae94472f9797f2e3396.jpg',
#  'id_ad2fb873471f0f89f5e815c2.jpg',
#  'id_ad58dc455e9d6ad1ab122caf.jpg',
#  'id_adb9c0155011e29dcf138efe.jpg',
#  'id_add89257e1dee7efb5453675.jpg',
#  'id_ae00809f01c2a96771c1dfba.jpg',
#  'id_ae261ea92e4249ce64c1255f.jpg',
#  'id_ae45a31fc0c4ac0199c48b00.jpg',
#  'id_ae61ac43be2e5267bc038ddf.jpg',
#  'id_aecc93ad73fe2be589b2942f.jpg',
#  'id_af09d1e88ec42e26106c6e81.jpg',
#  'id_af44966f64bf5641c3c8fa3a.jpg',
#  'id_af53e4ca22f6c64e984ef277.jpg',
#  'id_af787728ecd816ae92475451.jpg',
#  'id_afa5f39fe9a57ef7d69e2df3.jpg',
#  'id_afcc24bded167ee6baa80cc8.jpg',
#  'id_aff5c8598129f7dc4a74ff57.jpg',
#  'id_b00b10a3d5b2ba193fdb97ef.jpg',
#  'id_b00c602d9c9a60269451be72.jpg',
#  'id_b0232777e4255c8c102337a9.jpg',
#  'id_b02d049f8b731466cd13be0e.jpg',
#  'id_b03b3d05a3eab799bf7aba6b.jpg',
#  'id_b04a4f975b18787913c8bf87.jpg',
#  'id_b0baa5de7355867753c18c7e.jpg',
#  'id_b0c366d158291ae2f383a2af.jpg',
#  'id_b0c4880d6859d0e617304f44.jpg',
#  'id_b0ecf0305c5794396499d82f.jpg',
#  ...]

# %%
np.save(f'{MODEL_FOLDER}/test_preds.npy',test_preds)

# %%
OOF_preds
# Out:
# array([[5.3787e-04, 1.0000e+00],
#        [3.8700e-03, 9.6484e-01],
#        [1.8341e-02, 1.3275e-02],
#        ...,
#        [6.5136e-04, 9.9512e-01],
#        [4.5395e-03, 9.9805e-01],
#        [3.9005e-03, 9.8193e-01]], dtype=float16)

# %%
np.save(f'{MODEL_FOLDER}/oof_ids.npy',OOF_ids)

# %%
np.save(f'{MODEL_FOLDER}/oof_preds.npy',OOF_preds)

# %% [markdown]
# ### Fin
